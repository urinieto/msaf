# %%
# Plotting some stuff for my Dissertation

from msaf import io
from msaf import plotting

reload(io)
reload(plotting)

est_file = "/Users/uri/datasets/Segments/estimations/Isophonics_05_-_And_I_Love_Her.json"
# est_file = "/Users/uri/datasets/Segments/estimations/Isophonics_01_-_Come_Together.json"
# est_file = "/Users/uri/datasets/Segments/estimations/Isophonics_06_-_I_Am_The_Walrus.json"
annot_beats = False
bound_algo_ids = ["cnmf3", "serra", "levy", "siplca", "foote", "olda"]
all_boundaries = io.get_all_est_boundaries(est_file, annot_beats, bound_algo_ids)
plotting.plot_boundaries(all_boundaries, est_file, bound_algo_ids, title="",
                         output_file="bounds_comparison.pdf")

label_algo_ids = ["cnmf3", "levy", "siplca", "2dfmc"]
gt_times, all_labels = io.get_all_est_labels(est_file, annot_beats, label_algo_ids)
plotting.plot_labels(all_labels, gt_times, est_file, label_algo_ids, title="",
                     output_file="labels_comparison.pdf")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-91-0d0f1d7590c6> in <module>()
#      19 gt_times, all_labels = io.get_all_est_labels(est_file, annot_beats, label_algo_ids)
#      20 plotting.plot_labels(all_labels, gt_times, est_file, label_algo_ids, title="",
# ---> 21                      output_file="labels_comparison.pdf")
#
# /Users/uri/NYU/Dissertation/msaf/plotting.pyc in plot_labels(all_labels, gt_times, est_file, algo_ids, title, output_file)
#     124
#     125     # To intervals
# --> 126     gt_inters = EV.times_to_intervals(gt_times)
#     127
#     128     # Plot labels
#
# AttributeError: 'module' object has no attribute 'times_to_intervals'
