# %%
import mir_eval
import sys
import os
import glob
import numpy as np
from pprint import pprint
import scipy.stats

# %%
ROOTPATH = '/home/bmcfee/git/olda/data/'

# %%
def load_annotations(path):
    
    files = sorted(glob.glob(path))
    
    data = [np.unique(mir_eval.io.load_annotation(f)[0].ravel()) for f in files]
    
    return data

# %%
def evaluate_set(SETNAME, agg=True):
    
    truth = load_annotations('%s/truth/%s/*' % (ROOTPATH, SETNAME))
    
    
    algos = map(os.path.basename, sorted(glob.glob('%s/predictions/%s/*' % (ROOTPATH, SETNAME))))
    
    scores = {}
    for A in algos:
        print 'Scoring %s...' % A
        # Load the corresponding predictions
        predictions = load_annotations('%s/predictions/%s/%s/*' % (ROOTPATH, SETNAME, A))
        
        # Scrub the predictions to valid ranges
        for i in range(len(predictions)):
            predictions[i] = mir_eval.util.adjust_times(predictions[i], t_max=truth[i][-1])[0]
            
        # Compute metrics
        my_scores = []
        
        for t, p in zip(truth, predictions):
            S = []
            S.extend(mir_eval.segment.boundary_detection(t, p, window=0.5))
            S.extend(mir_eval.segment.boundary_detection(t, p, window=3.0))
            S.extend(mir_eval.segment.boundary_deviation(t, p))
            S.extend(mir_eval.segment.frame_clustering_nce(t, p))
            S.extend(mir_eval.segment.frame_clustering_pairwise(t, p))
            S.extend(mir_eval.segment.frame_clustering_mi(t, p))
            S.append(mir_eval.segment.frame_clustering_ari(t, p))
            my_scores.append(S)
            
        my_scores = np.array(my_scores)
        if agg:
            scores[A] = np.mean(my_scores, axis=0)
        else:
            scores[A] = my_scores
        
    return scores

# %%
METRICS = ['BD.5 P', 'BD.5 R', 'BD.5 F', 
           'BD3 P', 'BD3 R', 'BD3 F', 
           'BDev T2P', 'BDev P2T', 
           'S_O', 'S_U', 'S_F', 
           'Pair_P', 'Pair_R', 'Pair_F', 
           'MI', 'AMI', 'NMI', 'ARI']

# %%
def save_results(outfile, predictions):
    
    with open(outfile, 'w') as f:
        f.write('%s,%s\n' % ('Algorithm', ','.join(METRICS)))
        
        for k in predictions:
            f.write('%s,%s\n' % (k, ','.join(map(lambda x: '%.8f' % x, predictions[k]))))

# %%
def plot_score_histograms(data):
    
    figure(figsize=(16,10))
    for i in range(len(METRICS)):
        subplot(6,3, i+1)
        hist(data[:, i], normed=True)
        xlim([0.0, max(1.0, np.max(data[:, i]))])
        legend([METRICS[i]])

# %%
def plot_boxes(data):
    figure(figsize=(10,8))
    for i in range(len(METRICS)):
        subplot(6, 3, i+1)
        my_data = []
        leg = []
        for k in data:
            leg.append(k)
            my_data.append(data[k][:, i])
        my_data = np.array(my_data).T
        boxplot(my_data)
        xticks(range(1, 1+len(data)), leg)
        ylim([0, max(1.0, my_data.max())])
        tight_layout()
        title(METRICS[i])

# %%
def get_top_sig(SETNAME, perfs, idx, p=0.05):
    
    # Pluck out the relevant algorithm
    data = {}
    mean = {}
    best_mean = -np.inf
    best_alg  = None
    n_algs    = len(perfs)
    
    for k in perfs:
        data[k] = perfs[k][:, idx]
        mean[k] = np.mean(data[k])
        if mean[k] > best_mean:
            best_mean = mean[k]
            best_alg = k
    
    
    
    # Compute pairwise tests against the best
    sigdiff = {}
    for k in perfs:
        if k == best_alg:
            sigdiff[k] = 1.0
            continue
        # Get the p-value
        _z, _p = scipy.stats.wilcoxon(data[best_alg], data[k])
        sigdiff[k] = _p
        
        
    # Print the results
    ordering = [(v, k) for k, v in mean.iteritems()]
    ordering.sort(reverse=True)
    
    print '%s\t%s' % (METRICS[idx], SETNAME)
    
    for (v, k) in ordering:
        print '%.3f\t%10s\t%.3e\t%r' % (v, k, sigdiff[k], sigdiff[k] * (n_algs -1) < p)

# %%
def get_worst_examples(SETNAME, perfs, algorithm, idx, k=10):
    files = sorted(map(os.path.basename, glob.glob('%s/predictions/%s/%s/*' % (ROOTPATH, SETNAME, algorithm))))
    
    
    indices = np.argsort(perfs[algorithm][:, idx])[:k]
    
    print '%s\t%s\t%s' % (METRICS[idx], SETNAME, algorithm)
    for v in indices:
        print '%.3f\t%s' % (perfs[algorithm][v, idx], files[v])

# %%
ind_perfs_billboard = evaluate_set('BILLBOARD', agg=False)
perfs_billboard = {}
for alg in ind_perfs_billboard:
    perfs_billboard[alg] = np.mean(ind_perfs_billboard[alg], axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-2a1e982bdd9b> in <module>()
# ----> 1 ind_perfs_billboard = evaluate_set('BILLBOARD', agg=False)
#       2 perfs_billboard = {}
#       3 for alg in ind_perfs_billboard:
#       4     perfs_billboard[alg] = np.mean(ind_perfs_billboard[alg], axis=0)
#
# <ipython-input-17-194984ad8a6c> in evaluate_set(SETNAME, agg)
#       1 def evaluate_set(SETNAME, agg=True):
#       2
# ----> 3     truth = load_annotations('%s/truth/%s/*' % (ROOTPATH, SETNAME))
#       4
#       5     algos = map(os.path.basename, sorted(glob.glob('%s/predictions/%s/*' % (ROOTPATH, SETNAME))))
#
# <ipython-input-16-ca3b76046c5b> in load_annotations(path)
#       3     files = sorted(glob.glob(path))
#       4
# ----> 5     data = [mir_eval.io.load_annotation(f)[0] for f in files]
#       6
#       7     return data
#
# /home/bmcfee/lib/python/mir_eval/io.pyc in load_annotation(filename, delimiter, converter, label_prefix)
#     118
#     119             if len(data) == 2:
# --> 120                 times.append([converter(data[0]), converter(data[1])])
#     121                 labels.append('%s%d' % (label_prefix, row))
#     122
#
# ValueError: could not convert string to float: silence

# %%
pprint(perfs_billboard)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-de93615ebeea> in <module>()
# ----> 1 pprint(perfs_billboard)
#
# NameError: name 'perfs_billboard' is not defined

# %%
for idx in range(len(METRICS)):
    get_top_sig('BILLBOARD', ind_perfs_billboard, idx=idx)
    print
# Out:
# BD.5 P	BILLBOARD
# 0.104	     unsup	1.000e+00	False
# 0.099	      rfda	1.899e-01	False
# 0.098	       fda	1.917e-02	False
# 0.094	      olda	1.193e-03	True
# 0.050	     smga1	1.039e-26	True
#
# BD.5 R	BILLBOARD
# 0.086	      rfda	1.000e+00	False
# 0.082	       fda	1.617e-01	False
# 0.079	      olda	7.078e-04	True
# 0.069	     unsup	1.980e-09	True
# 0.054	     smga1	6.062e-14	True
#
# BD.5 F	BILLBOARD
# 0.089	      rfda	1.000e+00	False
# 0.087	       fda	5.330e-01	False
# 0.083	      olda	3.032e-02	False
# 0.080	     unsup	3.958e-01	False
# 0.051	     smga1	1.153e-22	True
#
# BD3 P	BILLBOARD
# 0.345	     unsup	1.000e+00	False
# 0.342	     smga1	9.907e-01	False
# 0.341	      rfda	2.481e-01	False
# 0.337	       fda	6.256e-02	False
# 0.333	      olda	1.034e-02	True
#
# BD3 R	BILLBOARD
# 0.374	     smga1	1.000e+00	False
# 0.282	      rfda	2.649e-35	True
# 0.273	       fda	2.827e-39	True
# 0.267	      olda	3.066e-43	True
# 0.228	     unsup	4.482e-68	True
#
# BD3 F	BILLBOARD
# 0.348	     smga1	1.000e+00	False
# 0.299	      rfda	1.993e-16	True
# 0.291	       fda	3.360e-19	True
# 0.286	      olda	3.573e-22	True
# 0.266	     unsup	3.927e-34	True
#
# BDev T2P	BILLBOARD
# 9.100	     unsup	1.000e+00	False
# 7.585	       fda	4.636e-46	True
# 7.409	      olda	9.654e-55	True
# 7.038	      rfda	9.397e-67	True
# 5.002	     smga1	3.029e-107	True
#
# BDev P2T	BILLBOARD
# 5.599	      olda	1.000e+00	False
# 5.567	       fda	5.992e-01	False
# 5.519	      rfda	4.008e-02	False
# 5.488	     unsup	1.377e-01	False
# 5.419	     smga1	5.899e-02	False
#
# S_O	BILLBOARD
# 0.811	     unsup	1.000e+00	False
# 0.790	       fda	1.802e-56	True
# 0.789	      olda	5.681e-60	True
# 0.785	      rfda	3.012e-70	True
# 0.746	     smga1	3.150e-112	True
#
# S_U	BILLBOARD
# 0.792	     smga1	1.000e+00	False
# 0.740	      rfda	1.506e-86	True
# 0.731	      olda	2.012e-94	True
# 0.728	       fda	2.223e-94	True
# 0.694	     unsup	2.716e-118	True
#
# S_F	BILLBOARD
# 0.762	     smga1	1.000e+00	False
# 0.755	      rfda	2.871e-07	True
# 0.752	      olda	2.939e-12	True
# 0.751	       fda	5.497e-14	True
# 0.741	     unsup	1.402e-33	True
#
# Pair_P	BILLBOARD
# 0.721	     unsup	1.000e+00	False
# 0.672	       fda	7.089e-70	True
# 0.671	      olda	7.356e-73	True
# 0.660	      rfda	2.166e-86	True
# 0.568	     smga1	1.332e-116	True
#
# Pair_R	BILLBOARD
# 0.632	     smga1	1.000e+00	False
# 0.560	      rfda	1.833e-67	True
# 0.549	      olda	1.173e-76	True
# 0.543	       fda	1.486e-81	True
# 0.508	     unsup	2.281e-101	True
#
# Pair_F	BILLBOARD
# 0.579	      rfda	1.000e+00	False
# 0.577	      olda	1.750e-02	False
# 0.574	       fda	1.011e-05	True
# 0.573	     unsup	4.564e-04	True
# 0.566	     smga1	4.505e-07	True
#
# MI	BILLBOARD
# 1.689	     smga1	1.000e+00	False
# 1.559	      rfda	5.828e-87	True
# 1.537	      olda	4.530e-95	True
# 1.530	       fda	1.042e-94	True
# 1.446	     unsup	1.846e-118	True
#
# AMI	BILLBOARD
# 0.686	     smga1	1.000e+00	False
# 0.674	      rfda	8.214e-06	True
# 0.667	      olda	2.694e-11	True
# 0.664	       fda	1.488e-14	True
# 0.642	     unsup	2.957e-33	True
#
# NMI	BILLBOARD
# 0.743	     smga1	1.000e+00	False
# 0.732	      rfda	1.022e-17	True
# 0.728	      olda	5.493e-25	True
# 0.726	       fda	8.809e-30	True
# 0.718	     unsup	1.175e-46	True
#
# ARI	BILLBOARD
# 0.511	      rfda	1.000e+00	False
# 0.507	      olda	3.407e-03	True
# 0.504	     smga1	8.332e-03	True
# 0.504	       fda	2.707e-07	True
# 0.497	     unsup	2.321e-08	True

# %%
ind_perfs_beatles = evaluate_set('BEATLES', agg=False)
perfs_beatles = {}
for alg in ind_perfs_beatles:
    perfs_beatles[alg] = np.mean(ind_perfs_beatles[alg], axis=0)
# Out:
# Scoring fda...
# Scoring olda...
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# Scoring rfda...
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# ...
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]

# %%
pprint(perfs_beatles)
# Out:
# {'fda': array([ 0.30836108,  0.29485141,  0.29212205,  0.57569082,  0.52932913,
#         0.53720954,  3.15050559,  3.05041899,  0.8311631 ,  0.79559268,
#         0.80710451,  0.74709002,  0.66865449,  0.6850969 ,  1.60337023,
#         0.73325908,  0.78929134,  0.62754904]),
#  'olda': array([ 0.3141119 ,  0.32076614,  0.3064522 ,  0.57172189,  0.55290544,
#         0.54707197,  2.84492458,  2.99930447,  0.82816996,  0.8081025 ,
#         0.81207067,  0.7383931 ,  0.68566835,  0.6900795 ,  1.63100981,
#         0.73839664,  0.79442688,  0.63446091]),
#  'rfda': array([ 0.31088972,  0.31743624,  0.30307007,  0.58193422,  0.5610429 ,
#         0.55564894,  2.82222346,  3.07215922,  0.82853976,  0.80655225,
#         0.81122721,  0.73919918,  0.6827685 ,  0.68787003,  1.62864529,
#         0.73635922,  0.79340736,  0.63146955]),
#  'smga1': array([ 0.14448849,  0.16943113,  0.15311947,  0.62092775,  0.72784284,
#         0.65786475,  1.87511341,  3.19086285,  0.81081623,  0.85841287,
#         0.82895447,  0.70171077,  0.79830693,  0.72932941,  1.75714723,
#         0.7648768 ,  0.81191605,  0.6831168 ]),
#  'unsup': array([ 0.30676543,  0.24303482,  0.26318316,  0.5843366 ,  0.45026817,
#         0.49679838,  4.42667877,  2.99784358,  0.84897079,  0.74727824,
#         0.78863884,  0.78758298,  0.60129252,  0.66167721,  1.49358247,
#         0.69846101,  0.7700679 ,  0.59583101])}

# %%
save_results('/home/bmcfee/git/olda/data/final_beatles_scores.csv', perfs_beatles)

# %%
del ind_perfs_beatles['rfda']

# %%
for idx in range(len(METRICS)):
    get_top_sig('BEATLES', ind_perfs_beatles, idx=idx)
    print
# Out:
# BD.5 P	BEATLES
# 0.314	      olda	1.000e+00	False
# 0.308	       fda	5.780e-01	False
# 0.307	     unsup	6.378e-01	False
# 0.144	     smga1	1.248e-18	True
#
# BD.5 R	BEATLES
# 0.321	      olda	1.000e+00	False
# 0.295	       fda	6.652e-03	True
# 0.243	     unsup	1.338e-10	True
# 0.169	     smga1	1.332e-12	True
#
# BD.5 F	BEATLES
# 0.306	      olda	1.000e+00	False
# 0.292	       fda	2.037e-01	False
# 0.263	     unsup	1.325e-04	True
# 0.153	     smga1	7.514e-16	True
#
# BD3 P	BEATLES
# 0.621	     smga1	1.000e+00	False
# 0.584	     unsup	3.441e-02	False
# 0.576	       fda	1.250e-02	True
# 0.572	      olda	6.123e-03	True
#
# BD3 R	BEATLES
# 0.728	     smga1	1.000e+00	False
# 0.553	      olda	1.385e-13	True
# 0.529	       fda	1.828e-15	True
# 0.450	     unsup	1.984e-22	True
#
# BD3 F	BEATLES
# 0.658	     smga1	1.000e+00	False
# 0.547	      olda	1.219e-08	True
# 0.537	       fda	1.037e-09	True
# 0.497	     unsup	2.048e-13	True
#
# BDev T2P	BEATLES
# 4.427	     unsup	1.000e+00	False
# 3.151	       fda	2.070e-10	True
# 2.845	      olda	1.005e-14	True
# 1.875	     smga1	6.842e-19	True
#
# BDev P2T	BEATLES
# 3.191	     smga1	1.000e+00	False
# 3.050	       fda	9.357e-01	False
# 2.999	      olda	8.571e-01	False
# 2.998	     unsup	6.857e-01	False
#
# S_O	BEATLES
# 0.849	     unsup	1.000e+00	False
# 0.831	       fda	9.344e-08	True
# 0.828	      olda	5.852e-08	True
# 0.811	     smga1	1.239e-10	True
#
# S_U	BEATLES
# 0.858	     smga1	1.000e+00	False
# 0.808	      olda	6.004e-12	True
# 0.796	       fda	8.839e-16	True
# 0.747	     unsup	1.750e-25	True
#
# S_F	BEATLES
# 0.829	     smga1	1.000e+00	False
# 0.812	      olda	8.765e-04	True
# 0.807	       fda	1.623e-05	True
# 0.789	     unsup	1.758e-10	True
#
# Pair_P	BEATLES
# 0.788	     unsup	1.000e+00	False
# 0.747	       fda	9.200e-11	True
# 0.738	      olda	2.311e-12	True
# 0.702	     smga1	1.772e-13	True
#
# Pair_R	BEATLES
# 0.798	     smga1	1.000e+00	False
# 0.686	      olda	5.713e-16	True
# 0.669	       fda	1.117e-18	True
# 0.601	     unsup	2.973e-26	True
#
# Pair_F	BEATLES
# 0.729	     smga1	1.000e+00	False
# 0.690	      olda	3.099e-04	True
# 0.685	       fda	4.140e-05	True
# 0.662	     unsup	3.153e-08	True
#
# MI	BEATLES
# 1.757	     smga1	1.000e+00	False
# 1.631	      olda	2.874e-13	True
# 1.603	       fda	8.797e-17	True
# 1.494	     unsup	6.308e-26	True
#
# AMI	BEATLES
# 0.765	     smga1	1.000e+00	False
# 0.738	      olda	4.524e-04	True
# 0.733	       fda	4.955e-05	True
# 0.698	     unsup	3.846e-10	True
#
# NMI	BEATLES
# 0.812	     smga1	1.000e+00	False
# 0.794	      olda	5.947e-04	True
# 0.789	       fda	1.044e-05	True
# 0.770	     unsup	1.193e-10	True
#
# ARI	BEATLES
# 0.683	     smga1	1.000e+00	False
# 0.634	      olda	1.366e-04	True
# 0.628	       fda	6.706e-06	True
# 0.596	     unsup	2.384e-09	True

# %%
plot_boxes(ind_perfs_beatles)

# %%
for alg in sorted(ind_perfs_beatles.keys()):
    get_worst_examples('BEATLES', ind_perfs_beatles, alg, 10, 10)
    print
# Out:
# S_F	BEATLES	fda
# 0.587	05_-_Dig_It.lab
# 0.605	09_-_You_Never_Give_Me_Your_Money.lab
# 0.607	11_-_Mean_Mr_Mustard.lab
# 0.679	03_-_Baby's_In_Black.lab
# 0.682	CD2_-_06_-_Helter_Skelter.lab
# 0.693	08_-_Love_Me_Do.lab
# 0.695	07_-_Please_Please_Me.lab
# 0.697	09_-_I'll_Cry_Instead.lab
# 0.704	12_-_A_Taste_Of_Honey.lab
# 0.717	01_-_I_Saw_Her_Standing_There.lab
#
# S_F	BEATLES	olda
# 0.524	05_-_Dig_It.lab
# 0.629	09_-_You_Never_Give_Me_Your_Money.lab
# 0.684	CD2_-_06_-_Helter_Skelter.lab
# 0.690	08_-_Love_Me_Do.lab
# 0.709	CD2_-_09_-_Honey_Pie.lab
# 0.717	01_-_I_Saw_Her_Standing_There.lab
# 0.717	CD1_-_06_-_The_Continuing_Story_of_Bungalow_Bill.lab
# 0.723	12_-_A_Taste_Of_Honey.lab
# 0.725	02_-_Misery.lab
# 0.726	14_-_Golden_Slumbers.lab
#
# S_F	BEATLES	smga1
# 0.455	07_-_Maggie_Mae.lab
# 0.574	09_-_You_Never_Give_Me_Your_Money.lab
# 0.657	12_-_Polythene_Pam.lab
# 0.676	10_-_Baby_It's_You.lab
# 0.693	11_-_Mean_Mr_Mustard.lab
# 0.698	16_-_The_End.lab
# 0.701	06_-_I_Want_You.lab
# 0.718	CD2_-_06_-_Helter_Skelter.lab
# 0.719	12_-_Sgt._Pepper's_Lonely_Hearts_Club_Band_(Reprise).lab
# 0.721	CD1_-_06_-_The_Continuing_Story_of_Bungalow_Bill.lab
#
# S_F	BEATLES	unsup
# 0.583	05_-_Dig_It.lab
# 0.603	09_-_You_Never_Give_Me_Your_Money.lab
# 0.656	08_-_Love_Me_Do.lab
# 0.659	11_-_Mean_Mr_Mustard.lab
# 0.660	09_-_I'll_Cry_Instead.lab
# 0.673	10_-_Sun_King.lab
# 0.678	07_-_Can't_Buy_Me_Love.lab
# 0.680	05_-_Another_Girl.lab
# 0.684	02_-_Misery.lab
# 0.686	02_-_With_A_Little_Help_From_My_Friends.lab

# %%
ind_perfs_salami = evaluate_set('SALAMI', agg=False)
perfs_salami = {}
for alg in ind_perfs_salami:
    perfs_salami[alg] = np.mean(ind_perfs_salami[alg], axis=0)
# Out:
# Scoring CNMF...
# Scoring SIPLCA...
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# Scoring fda...
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
# ...
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:133: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[:last_idx[0]]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]
# /home/bmcfee/lib/python/mir_eval/util.py:117: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   times = times[first_idx[0]:]

# %%
pprint(perfs_salami)
# Out:
# {'CNMF': array([ 0.10514414,  0.13322015,  0.10971976,  0.45024537,  0.54333524,
#         0.46309017,  4.1670073 ,  5.94623858,  0.76659964,  0.7972802 ,
#         0.76675763,  0.57638598,  0.63895335,  0.55031555,  1.77360763,
#         0.66952316,  0.74624826,  0.49008302]),
#  'SIPLCA': array([  0.2100008 ,   0.10169394,   0.12774307,   0.45112871,
#          0.22782295,   0.28610934,  16.93411006,   5.80685512,
#          0.8733449 ,   0.53755385,   0.64316976,   0.8135197 ,
#          0.36192509,   0.45888541,   1.1118125 ,   0.4785737 ,
#          0.6205327 ,   0.34372012]),
#  'fda': array([ 0.24981792,  0.22641893,  0.22959561,  0.50265383,  0.46694354,
#         0.4674181 ,  4.97121442,  5.35690117,  0.80247709,  0.82729804,
#         0.80593287,  0.63702456,  0.70151722,  0.6351471 ,  1.84763991,
#         0.73843458,  0.79456643,  0.58547391]),
#  'olda': array([ 0.25614113,  0.23859743,  0.23991921,  0.49790654,  0.47008767,
#         0.46834577,  4.52866823,  5.49527389,  0.79582704,  0.83655054,
#         0.80691497,  0.62238766,  0.71929829,  0.63563952,  1.87253066,
#         0.74257522,  0.79725941,  0.58781235]),
#  'rfda': array([ 0.25800108,  0.23525312,  0.23815098,  0.50489416,  0.47215446,
#         0.47142707,  4.67628738,  5.4641213 ,  0.79879476,  0.83234977,
#         0.80609063,  0.62749685,  0.7091495 ,  0.63239468,  1.85973532,
#         0.74008136,  0.79620676,  0.58368002]),
#  'smga1': array([ 0.11493075,  0.17796945,  0.13437579,  0.43375133,  0.6661867 ,
#         0.5076943 ,  2.09821367,  7.15111203,  0.71435089,  0.89521267,
#         0.78623916,  0.4482276 ,  0.82188953,  0.55046362,  2.02822911,
#         0.68987443,  0.78058019,  0.50768952]),
#  'unsup': array([ 0.23687438,  0.18267191,  0.20015196,  0.5004068 ,  0.39415152,
#         0.42673388,  6.81879263,  5.79621318,  0.81287353,  0.78900142,
#         0.79145047,  0.669992  ,  0.64209454,  0.62171533,  1.75163859,
#         0.71798324,  0.7789335 ,  0.56617861])}

# %%
save_results('/home/bmcfee/git/olda/data/final_salami_scores.csv', perfs_salami)

# %%
for alg in sorted(ind_perfs_salami.keys()):
    get_worst_examples('SALAMI', ind_perfs_salami, alg, 10, 5)
    print
# Out:
# S_F	SALAMI	CNMF
# 0.000	964.lab
# 0.381	1376.lab
# 0.432	968.lab
# 0.449	1420.lab
# 0.587	1074.lab
#
# S_F	SALAMI	SIPLCA
# 0.000	964.lab
# 0.222	1432.lab
# 0.239	1192.lab
# 0.279	1152.lab
# 0.308	1422.lab
#
# S_F	SALAMI	fda
# 0.000	964.lab
# 0.258	1376.lab
# 0.465	1462.lab
# 0.556	1226.lab
# 0.625	1134.lab
#
# S_F	SALAMI	olda
# 0.000	964.lab
# 0.189	1376.lab
# 0.436	1462.lab
# 0.553	1226.lab
# 0.605	1136.lab
#
# S_F	SALAMI	rfda
# 0.000	964.lab
# 0.206	1376.lab
# 0.446	1462.lab
# 0.509	1226.lab
# 0.624	1482.lab
#
# S_F	SALAMI	smga1
# 0.000	964.lab
# 0.203	1376.lab
# 0.349	1462.lab
# 0.495	1226.lab
# 0.540	1062.lab
#
# S_F	SALAMI	unsup
# 0.000	964.lab
# 0.238	1376.lab
# 0.439	1462.lab
# 0.537	1226.lab
# 0.630	1062.lab

# %%
del ind_perfs_salami['rfda']

# %%
for idx in range(len(METRICS)):
    get_top_sig('SALAMI', ind_perfs_salami, idx=idx)
    print
# Out:
# BD.5 P	SALAMI
# 0.256	      olda	1.000e+00	False
# 0.250	       fda	3.358e-01	False
# 0.237	     unsup	3.803e-03	True
# 0.210	    SIPLCA	7.714e-04	True
# 0.115	     smga1	2.230e-31	True
# 0.105	      CNMF	2.378e-29	True
#
# BD.5 R	SALAMI
# 0.239	      olda	1.000e+00	False
# 0.226	       fda	2.433e-02	False
# 0.183	     unsup	3.718e-13	True
# 0.178	     smga1	3.059e-07	True
# 0.133	      CNMF	7.822e-17	True
# 0.102	    SIPLCA	9.197e-26	True
#
# BD.5 F	SALAMI
# 0.240	      olda	1.000e+00	False
# 0.230	       fda	1.173e-01	False
# 0.200	     unsup	8.508e-09	True
# 0.134	     smga1	3.318e-22	True
# 0.128	    SIPLCA	7.034e-20	True
# 0.110	      CNMF	4.955e-26	True
#
# BD3 P	SALAMI
# 0.503	       fda	1.000e+00	False
# 0.500	     unsup	6.499e-01	False
# 0.498	      olda	3.767e-01	False
# 0.451	    SIPLCA	3.960e-04	True
# 0.450	      CNMF	7.339e-05	True
# 0.434	     smga1	4.154e-10	True
#
# BD3 R	SALAMI
# 0.666	     smga1	1.000e+00	False
# 0.543	      CNMF	1.977e-14	True
# 0.470	      olda	7.998e-28	True
# 0.467	       fda	1.211e-26	True
# 0.394	     unsup	3.777e-37	True
# 0.228	    SIPLCA	6.485e-42	True
#
# BD3 F	SALAMI
# 0.508	     smga1	1.000e+00	False
# 0.468	      olda	4.866e-04	True
# 0.467	       fda	4.454e-04	True
# 0.463	      CNMF	4.183e-05	True
# 0.427	     unsup	2.231e-12	True
# 0.286	    SIPLCA	5.717e-34	True
#
# BDev T2P	SALAMI
# 16.934	    SIPLCA	1.000e+00	False
# 6.819	     unsup	1.469e-33	True
# 4.971	       fda	2.349e-38	True
# 4.529	      olda	6.394e-40	True
# 4.167	      CNMF	3.119e-41	True
# 2.098	     smga1	3.570e-43	True
#
# BDev P2T	SALAMI
# 7.151	     smga1	1.000e+00	False
# 5.946	      CNMF	4.591e-03	True
# 5.807	    SIPLCA	5.163e-04	True
# 5.796	     unsup	5.099e-10	True
# 5.495	      olda	2.228e-13	True
# 5.357	       fda	3.934e-11	True
#
# S_O	SALAMI
# 0.873	    SIPLCA	1.000e+00	False
# 0.813	     unsup	1.762e-26	True
# 0.802	       fda	1.228e-32	True
# 0.796	      olda	1.256e-33	True
# 0.767	      CNMF	2.641e-37	True
# 0.714	     smga1	3.834e-43	True
#
# S_U	SALAMI
# 0.895	     smga1	1.000e+00	False
# 0.837	      olda	4.660e-32	True
# 0.827	       fda	8.098e-34	True
# 0.797	      CNMF	1.069e-37	True
# 0.789	     unsup	1.041e-41	True
# 0.538	    SIPLCA	4.407e-43	True
#
# S_F	SALAMI
# 0.807	      olda	1.000e+00	False
# 0.806	       fda	3.596e-01	False
# 0.791	     unsup	1.202e-10	True
# 0.786	     smga1	1.428e-11	True
# 0.767	      CNMF	1.281e-20	True
# 0.643	    SIPLCA	9.282e-36	True
#
# Pair_P	SALAMI
# 0.814	    SIPLCA	1.000e+00	False
# 0.670	     unsup	5.356e-32	True
# 0.637	       fda	8.645e-38	True
# 0.622	      olda	7.397e-39	True
# 0.576	      CNMF	1.053e-36	True
# 0.448	     smga1	2.987e-43	True
#
# Pair_R	SALAMI
# 0.822	     smga1	1.000e+00	False
# 0.719	      olda	1.091e-28	True
# 0.702	       fda	6.794e-31	True
# 0.642	     unsup	4.604e-40	True
# 0.639	      CNMF	1.191e-35	True
# 0.362	    SIPLCA	5.271e-43	True
#
# Pair_F	SALAMI
# 0.636	      olda	1.000e+00	False
# 0.635	       fda	7.905e-01	False
# 0.622	     unsup	1.866e-03	True
# 0.550	     smga1	2.203e-25	True
# 0.550	      CNMF	3.737e-19	True
# 0.459	    SIPLCA	3.234e-26	True
#
# MI	SALAMI
# 2.028	     smga1	1.000e+00	False
# 1.873	      olda	1.333e-32	True
# 1.848	       fda	4.007e-34	True
# 1.774	      CNMF	9.552e-38	True
# 1.752	     unsup	8.307e-42	True
# 1.112	    SIPLCA	3.059e-43	True
#
# AMI	SALAMI
# 0.743	      olda	1.000e+00	False
# 0.738	       fda	7.210e-02	False
# 0.718	     unsup	5.251e-11	True
# 0.690	     smga1	2.532e-20	True
# 0.670	      CNMF	1.046e-24	True
# 0.479	    SIPLCA	2.077e-38	True
#
# NMI	SALAMI
# 0.797	      olda	1.000e+00	False
# 0.795	       fda	5.814e-02	False
# 0.781	     smga1	8.150e-08	True
# 0.779	     unsup	5.926e-13	True
# 0.746	      CNMF	1.051e-26	True
# 0.621	    SIPLCA	2.742e-40	True
#
# ARI	SALAMI
# 0.588	      olda	1.000e+00	False
# 0.585	       fda	4.540e-01	False
# 0.566	     unsup	3.829e-05	True
# 0.508	     smga1	2.289e-22	True
# 0.490	      CNMF	1.122e-20	True
# 0.344	    SIPLCA	7.266e-32	True

# %%
plot_boxes(ind_perfs_salami)

# %% [markdown]
# # Figures

# %%
import librosa
import scipy.signal
import functools

# %%
def get_beat_mfccs(filename):
    y, sr = librosa.load(filename)
    
    S = librosa.feature.melspectrogram(y, sr, n_fft=2048, hop_length=64, n_mels=128, fmax=8000)
    
    tempo, beats = librosa.beat.beat_track(y=y, sr=sr, hop_length=64)
    
    M = librosa.feature.mfcc(librosa.logamplitude(S), n_mfcc=32)
    M = librosa.feature.sync(M, beats)
    return M

# %%
def compress_data(X, k):
    sigma = np.cov(X)
    e_vals, e_vecs = scipy.linalg.eig(sigma)
        
    e_vals = np.maximum(0.0, np.real(e_vals))
    e_vecs = np.real(e_vecs)
        
    idx = np.argsort(e_vals)[::-1]
        
    e_vals = e_vals[idx]
    e_vecs = e_vecs[:, idx]
        
    # Truncate to k dimensions
    if k < len(e_vals):
        e_vals = e_vals[:k]
        e_vecs = e_vecs[:, :k]
        
    # Normalize by the leading singular value of X
    Z = np.sqrt(e_vals.max())
        
    if Z > 0:
        e_vecs = e_vecs / Z
        
    return e_vecs.T.dot(X)

# %%
def make_rep_feature_plot(M):
    
    R = librosa.segment.recurrence_matrix(M, metric='seuclidean')
    
    Rskew = librosa.segment.structure_feature(R)
    Rskew = np.roll(Rskew, M.shape[1], axis=0)
    
    
    Rfilt = scipy.signal.medfilt2d(Rskew.astype(np.float32), kernel_size=(1, 7))
    #Rfilt = Rfilt[Rfilt.sum(axis=1) > 0, :]
    
    Rlatent = compress_data(Rfilt, 8)
    #Rlatent = compress_data(Rfilt, R.shape[0])
    
    figure(figsize=(6,6))
    subplot(221)
    librosa.display.specshow(R), title('Self-similarity')
    xlabel('Beat'), ylabel('Beat')
    xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    yticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    
    subplot(222)
    librosa.display.specshow(Rskew, cmap='gray_r'), title('Skewed self-sim.')
    xlabel('Beat'), ylabel('Lag')
    yticks(range(0, Rskew.shape[0] + 1, Rskew.shape[0] / 6), range(-M.shape[1]+2, 1+M.shape[1], Rskew.shape[0] / 6))
    xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    
    subplot(223)
    librosa.display.specshow(Rfilt, cmap='gray_r'), title('Filtered self-sim.')
    xlabel('Beat'), ylabel('Lag')
    yticks(range(0, Rskew.shape[0] + 1, Rskew.shape[0] / 6), range(-M.shape[1]+2, 1+M.shape[1], Rskew.shape[0] / 6))
    xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    
    subplot(224)
    librosa.display.specshow(Rlatent, origin='upper'), title('Latent repetition')
    xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    xlabel('Beat'), ylabel('Factor'), yticks(range(Rlatent.shape[0]))
    tight_layout()
    
    savefig('/home/bmcfee/git/olda/paper/figs/rep.pdf', format='pdf', pad_inches=0, transparent=True)
    #savefig('/home/bmcfee/git/olda/paper/figs/rep.svg', format='svg', pad_inches=0, transparent=True, dpi=200)

# %%
M = get_beat_mfccs('/home/bmcfee/data/CAL500/mp3/2pac-trapped.mp3')

# %%
make_rep_feature_plot(M)
# Out:
# /usr/lib/python2.7/dist-packages/scipy/spatial/distance.py:1176: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   dm = np.zeros((m * (m - 1) / 2,), dtype=np.double)

# %%
make_rep_feature_plot(M[:,40:137])
# Out:
# /usr/lib/python2.7/dist-packages/scipy/spatial/distance.py:1176: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   dm = np.zeros((m * (m - 1) / 2,), dtype=np.double)

# %%
model_fda = np.load('/home/bmcfee/git/olda/data/model_fda_salami.npy')
model_rfda = np.load('/home/bmcfee/git/olda/data/model_rfda_salami.npy')
model_olda  = np.load('/home/bmcfee/git/olda/data/model_olda_salami.npy')
figure(figsize=(8,10))
subplot(311)
librosa.display.specshow(model_fda, origin='upper')

ylabel('SALAMI: FDA')
yticks([])
#ylabel("More important $\\rightarrow$")
#xticks([0, 32, 44, 76, 108], ['MFCC', 'Chroma', 'Rep-M', 'Rep-C', 'Time'], rotation=-30, horizontalalignment='left')
xticks([])
#colorbar()

subplot(312)
librosa.display.specshow(model_rfda, origin='upper')
ylabel('SALAMI: RFDA')
#colorbar(orientation='horizontal')
#ylabel("More important $\\rightarrow$")
yticks([])


subplot(313)
librosa.display.specshow(model_olda, origin='upper')
ylabel('SALAMI: OLDA')
colorbar(orientation='horizontal', use_gridspec=True )
#ylabel("More important $\\rightarrow$")
yticks([])
xticks([0, 32, 44, 76, 108], ['MFCC', '$\uparrow$\nChroma', 'R-MFCC', 'R-Chroma', 'Time'], horizontalalignment='left')

tight_layout()
#savefig('/home/bmcfee/git/olda/paper/figs/w.pdf', format='pdf', pad_inches=0, transparent=True)

# %%
model_fda_beatles = np.load('/home/bmcfee/git/olda/data/model_fda_beatles.npy')
model_fda_salami = np.load('/home/bmcfee/git/olda/data/model_fda_salami.npy')
model_olda_beatles  = np.load('/home/bmcfee/git/olda/data/model_olda_beatles.npy')
model_olda_salami = np.load('/home/bmcfee/git/olda/data/model_olda_salami.npy')

figure(figsize=(14,8))
subplot(221)
imshow(model_fda_beatles, aspect='auto', interpolation='none', cmap='PRGn_r')
ylabel('FDA - Beatles')
yticks([])
xticks([])

subplot(222)
imshow(model_fda_salami, aspect='auto', interpolation='none', cmap='PRGn_r')
ylabel('FDA - Salami')
yticks([])
xticks([])

subplot(223)
imshow(model_olda_beatles, aspect='auto', interpolation='none', cmap='PRGn_r')
ylabel('OLDA - Beatles')
yticks([])
xticks([0, 32, 44, 76, 108], ['MFCC', '$\uparrow$\nChroma', 'R-MFCC', 'R-Chroma', 'Time'], horizontalalignment='left')

subplot(224)
imshow(model_olda_salami, aspect='auto', interpolation='none', cmap='PRGn_r')
ylabel('OLDA - Salami')
yticks([])
xticks([])
xticks([0, 32, 44, 76, 108], ['MFCC', '$\uparrow$\nChroma', 'R-MFCC', 'R-Chroma', 'Time'], horizontalalignment='left')

tight_layout()
#savefig('/home/bmcfee/git/olda/paper/figs/fda-vs-olda.pdf', format='pdf', pad_inches=0, transparent=True)

# %% [markdown]
# SVD stuff

# %%
def rep_feature_svd(M):
    
    myimshow = functools.partial(imshow, aspect='auto', interpolation='none', origin='lower', cmap='gray_r')
    
    R = librosa.segment.recurrence_matrix(M, k=2*np.sqrt(1./M.shape[1]), sym=False).astype(np.float)
    
    Rskew = librosa.segment.structure_feature(R, pad=True)
    Rskew = np.roll(Rskew, M.shape[1], axis=0)
    
    
    Rfilt = scipy.signal.medfilt2d(Rskew, kernel_size=(1, 7))
    #Rfilt = Rfilt[Rfilt.sum(axis=1) > 0, :]
    
    Rlatent = compress_data(Rfilt, 8)
    #Rlatent = compress_data(Rfilt, R.shape[0])
    
    figure(figsize=(12,4))
    subplot(131)
    myimshow(R), title('Self-similarity')
    xlabel('Beat'), ylabel('Beat')
    xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    yticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    
    subplot(132)
    myimshow(Rskew), title('Skewed self-sim.')
    xlabel('Beat'), ylabel('Lag')
    yticks(range(0, Rskew.shape[0] + 1, Rskew.shape[0] / 6), range(-M.shape[1]+1, M.shape[1], Rskew.shape[0] / 6))
    xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    
    subplot(133)
    myimshow(Rfilt), title('Filtered self-sim.')
    xlabel('Beat'), ylabel('Lag')
    yticks(range(0, Rskew.shape[0] + 1, Rskew.shape[0] / 6), range(-M.shape[1]+1, M.shape[1], Rskew.shape[0] / 6))
    xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    tight_layout()
    
    # Do the SVD
    U, sigma, Vh = scipy.linalg.svd(Rfilt)
    
    D_little = 32
    
    figure(figsize=(12,4))
    subplot(131)
    myimshow(U[:,:D_little], cmap='PRGn'), title('U')
    xlabel('Factor'), ylabel('Lag')
    #yticks(range(0, Rskew.shape[0] + 1, Rskew.shape[0] / 6), range(-M.shape[1]+1, M.shape[1], Rskew.shape[0] / 6))
    #xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    
    subplot(132)
    plot(sigma / sigma[0]), axis('tight'), title('Normalized spectrum $\sigma/\sigma_1$')
    vlines([D_little], 0, 1)
    
    subplot(133)
    myimshow(Vh[:D_little], cmap='PRGn'), title('V\'')
    xlabel('Beat'), ylabel('Factor')
    #yticks(range(0, Rskew.shape[0] + 1, Rskew.shape[0] / 6), range(-M.shape[1]+1, M.shape[1], Rskew.shape[0] / 6))
    #xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    tight_layout()
    # Reconstruct
    S_hat = np.zeros(U.shape[1])
    S_hat[:D_little] = sigma[:D_little]
    
    R_reconst = U.dot(np.diag(S_hat))
    R_reconst = R_reconst[:, :Vh.shape[0]].dot(Vh)
    
    figure(figsize=(12,6))
    subplot(121)
    myimshow(Rfilt), title('Original')
    subplot(122)
    myimshow(R_reconst), title('Reconstruction (d=%2d)' % D_little)
    tight_layout()
    
    figure(figsize=(16,32))
    
    for i in range(D_little):
        subplot(1+np.ceil(np.sqrt(D_little)), np.floor(np.sqrt(D_little)), i+1)
        myimshow(np.outer(U[:,i], Vh[i])), title('$U_{%d} V^\mathsf{T}_{%d}$' % (i, i))
    
    tight_layout()

# %%
rep_feature_svd(M)#[:,40:137])
